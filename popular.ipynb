# %%
import pandas as pd

# %%
dataset = pd.read_csv("spotify_dataset.csv", delimiter=',')
dataset = dataset.drop(columns=['text', 'Album', 'Release Date', 'Similar Artist 1', 'Similar Song 1', 'Similarity Score 1', 'Similar Artist 2', 'Similar Song 2', 'Similarity Score 2', 'Similar Artist 3', 'Similar Song 3', 'Similarity Score 3'])
dataset.head()
# Out:
#   Artist(s)                       song Length  emotion    Genre     Key  \
# 0       !!!  Even When the Waters Cold  03:47  sadness  hip hop   D min
# 1       !!!         One Girl / One Boy  04:03  sadness  hip hop  A# min
# 2       !!!          Pardon My Freedom  05:51      joy  hip hop   A Maj
# 3       !!!                        Ooo  03:44      joy  hip hop   A min
# 4       !!!                 Freedom 15  06:00      joy  hip hop   F min
#
#       Tempo  Loudness (db) Time signature Explicit  ...  Instrumentalness  \
# 0  0.437870       0.785065            4/4       No  ...                 0
# 1  0.508876       0.805051            4/4       No  ...                 0
# 2  0.532544       0.799419            4/4       No  ...                20
# 3  0.538462       0.811047            4/4       No  ...                 0
# 4  0.544379       0.808321            4/4       No  ...                 1
#
#    Good for Party  Good for Work/Study  Good for Relaxation/Meditation  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498052 entries, 0 to 498051
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Artist(s)                       498052 non-null  object
#  1   song                            498038 non-null  object
#  2   Length                          498052 non-null  object
#  3   emotion                         498052 non-null  object
#  4   Genre                           498052 non-null  object
#  5   Key                             498052 non-null  object
#  6   Tempo                           498052 non-null  float64
#  7   Loudness (db)                   498052 non-null  float64
#  8   Time signature                  498044 non-null  object
#  9   Explicit                        498052 non-null  object
#  10  Popularity                      498052 non-null  int64
#  11  Energy                          498052 non-null  int64
# ...
